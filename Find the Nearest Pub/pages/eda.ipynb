# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
col = pd.read_csv("data_dictionary.csv")

# %%
col.head()
# Out:
#       Field Possible Values                                 Comments
# 0    fsa_id             int  Food Standard Agency's ID for this pub.
# 1      name          string                         Name of the pub.
# 2   address          string      Address fields separated by commas.
# 3  postcode          string                     Postcode of the pub.
# 4   easting             int                                      NaN

# %%
data = pd.read_csv('open_pubs.csv')

# %%
df = pd.DataFrame(data = data.values, columns= col['Field'])

# %%
df.head()
# Out:
# Field fsa_id                name  \
# 0         36  Ark Bar Restaurant
# 1         74           Black Boy
# 2         75         Black Horse
# 3         76          Black Lion
# 4         97        Brewers Arms
#
# Field                                            address  postcode easting  \
# 0      Ark Bar And Restaurant, Cattawade Street, Bran...  CO11 1RH  610194
# 1      The Lady Elizabeth, 7 Market Hill, SUDBURY, Su...  CO10 2EA  587334
# 2            Lower Street, Stratford St Mary, COLCHESTER   CO7 6JS  622675
# 3                          Lion Road, Glemsford, SUDBURY  CO10 7RF  622675
# 4      The Brewers Arms, Bower House Tye, Polstead, C...   CO6 5BZ  598743
#
# Field  northing   latitude longitude local_authority
# 0        233329  51.958698  1.057832         Babergh
# 1        241316  52.038595  0.729915         Babergh
# 2      -5527598         \N        \N         Babergh
# 3      -5527598         \N        \N         Babergh
# ...

# %%
# as the ist row of data was taking as column names so have to add it again 
df.loc[0] = ['22','Anchor Inn', 'Upper Street, Stratford St Mary, COLCHESTER', 'CO7 6LW', '604749', '234404', '51.970379', '0.97934','Babergh' ]

# %%
df.head()
# Out:
# Field fsa_id          name                                            address  \
# 0         22    Anchor Inn        Upper Street, Stratford St Mary, COLCHESTER
# 1         74     Black Boy  The Lady Elizabeth, 7 Market Hill, SUDBURY, Su...
# 2         75   Black Horse        Lower Street, Stratford St Mary, COLCHESTER
# 3         76    Black Lion                      Lion Road, Glemsford, SUDBURY
# 4         97  Brewers Arms  The Brewers Arms, Bower House Tye, Polstead, C...
#
# Field  postcode easting  northing   latitude longitude local_authority
# 0       CO7 6LW  604749    234404  51.970379   0.97934         Babergh
# 1      CO10 2EA  587334    241316  52.038595  0.729915         Babergh
# 2       CO7 6JS  622675  -5527598         \N        \N         Babergh
# 3      CO10 7RF  622675  -5527598         \N        \N         Babergh
# 4       CO6 5BZ  598743    240655  52.028694  0.895650         Babergh

# %%
# remove all values with \N values taken as missing values
df.drop(df.index[df['latitude'] == '\\N' ], inplace=True)

# %%
df.head()
# Out:
# Field fsa_id             name  \
# 0         22       Anchor Inn
# 1         74        Black Boy
# 4         97     Brewers Arms
# 5        102     Bristol Arms
# 6        122  Caffeine Lounge
#
# Field                                            address  postcode easting  \
# 0            Upper Street, Stratford St Mary, COLCHESTER   CO7 6LW  604749
# 1      The Lady Elizabeth, 7 Market Hill, SUDBURY, Su...  CO10 2EA  587334
# 4      The Brewers Arms, Bower House Tye, Polstead, C...   CO6 5BZ  598743
# 5                         Bristol Hill, Shotley, IPSWICH   IP9 1PU  624624
# 6      14 Borehamgate Shopping Precinct, King Street,...  CO10 2ED  587527
#
# Field northing   latitude longitude local_authority
# 0       234404  51.970379   0.97934         Babergh
# 1       241316  52.038595  0.729915         Babergh
# 4       240655  52.028694  0.895650         Babergh
# 5       233550  51.955042  1.267642         Babergh
# 6       241247  52.037903  0.732687         Babergh

# %%
df.dtypes
# Out:
# Field
# fsa_id             object
# name               object
# address            object
# postcode           object
# easting            object
# northing           object
# latitude           object
# longitude          object
# local_authority    object
# dtype: object

# %%
df[['latitude', 'longitude']] = df[['latitude', 'longitude']].apply(pd.to_numeric)

# %%
df.dtypes
# Out:
# Field
# fsa_id              object
# name                object
# address             object
# postcode            object
# easting             object
# northing            object
# latitude           float64
# longitude          float64
# local_authority     object
# dtype: object

# %%
df.to_csv('modified_open_pubs.csv')
